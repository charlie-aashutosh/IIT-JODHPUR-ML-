# %% [markdown]
# <a href="https://colab.research.google.com/github/charlie-aashutosh/IIT-JODHPUR-ML-/blob/main/Naive_Bayes_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Case Study - 1 : Insurance data

# %%
data=pd.read_csv("/content/insurance2.csv")

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %%
data.isnull().sum()
# Out:
# age               0
# sex               0
# bmi               0
# children          0
# smoker            0
# region            0
# charges           0
# insuranceclaim    0
# dtype: int64

# %%
x=data.drop(['insuranceclaim'],axis=1)
y=data['insuranceclaim']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75)

# %%
from sklearn.naive_bayes import GaussianNB
nb_classifier=GaussianNB()

# %%
nb_classifier.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=nb_classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
ac=accuracy_score(y_test,y_pred)

# %%
print(cm)
# Out:
# [[129  13]
#  [ 58 135]]

# %%
print(ac)
# Out:
# 0.7880597014925373

# %% [markdown]
# Case Study - 2 : Marketing data

# %%
data_2=pd.read_csv("/content/Social_Network_Ads.csv")

# %%
data_2.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
data_2['Gender']=data_2['Gender'].apply({'Male':1,'Female':2}.get)

# %%
data_2.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       1   19            19000          0
# 1  15810944       1   35            20000          0
# 2  15668575       2   26            43000          0
# 3  15603246       2   27            57000          0
# 4  15804002       1   19            76000          0

# %%
data_2.drop(['User ID'],axis=1)
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         1   19            19000          0
# 1         1   35            20000          0
# 2         2   26            43000          0
# 3         2   27            57000          0
# 4         1   19            76000          0
# ..      ...  ...              ...        ...
# 395       2   46            41000          1
# 396       1   51            23000          1
# 397       2   50            20000          1
# 398       1   36            33000          0
# 399       2   49            36000          1
#
# [400 rows x 4 columns]

# %%
X=data_2[['Gender','Age','EstimatedSalary']] #x1, x2, x3
Y=data_2['Purchased'] #y

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.75)

# %%
nb_classifier.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
y_hat=nb_classifier.predict(X_test)

# %%
cm=confusion_matrix(y_hat,Y_test)
ac=accuracy_score(y_hat,Y_test)

# %%
print(cm)
# Out:
# [[61  4]
#  [ 7 28]]

# %%
print(ac)
# Out:
# 0.89
